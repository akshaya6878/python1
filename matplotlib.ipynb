# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaya6878/python1/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **pyplot**

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints= np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])


plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,marker= 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,marker= '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,'o:m')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,'*:m',ms=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,marker='*',ms=10,mec='m')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,marker='*',ms=10,mec='m',mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,marker='D',ms=10,mec='coral',mfc='chocolate')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,ls='--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.plot(xpoints,ypoints,ls='-',color='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])
plt.plot(xpoints,ypoints,ls='-',color='g',linewidth='5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2,4,6,8,10])
y1 = np.array([1,3,5,7,9])
x2 = np.array([2,3,5,7,6])
y2 = np.array([11,10,9,8,7])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.plot(x, y)

plt.title("marks of a student")
plt.xlabel("course name")
plt.ylabel("marks")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.plot(x, y)

plt.title("marks of a student")
plt.xlabel("course name")
plt.ylabel("marks")
plt.plot(x,y)
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.plot(x, y)

plt.title("marks of a student")
plt.xlabel("course name")
plt.ylabel("marks")
plt.plot(x,y)
plt.grid(axis='x')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.plot(x, y)

plt.title("marks of a student")
plt.xlabel("course name")
plt.ylabel("marks")
plt.plot(x,y)
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([1,3,7,9])
y = np.array([2,4,6,8])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([10,9,8,7])
y = np.array([1,2,3,4])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([1,3,7,9])
y = np.array([2,4,6,8])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([10,9,8,7])
y = np.array([1,2,3,4])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([8, 3, 7, 1])
y = np.array([2, 6, 1, 9])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("grade")

#plot 2:
x = np.array([4,5,6,7])
y = np.array([11,12,13,14])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("marks")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xpoints = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
ypoints = np.array([95,87,81,96,97,96,92,77])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x= np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,  "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.scatter(x,y, color = '#88c999')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x= np.array([100,200,300,400,500,600,700,800])
y = np.array([95,87,81,96,97,96,92,77])
plt.scatter(x,y, color = 'g')

x = np.array([150,250,350,450,550,650,750,850])
y= np.array([92,90,87,93,98,98,91,76])
plt.scatter(x,y, color = 'm')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.bar(x,y,color='m')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.bar(x,y,color='g',width=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"])
y = np.array([95,87,81,96,97,96,92,77])

plt.barh(x,y,color='hotpink',height=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(10,50,100)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
plt.pie(y, labels = mylabels, startangle = 180)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
myexplode=[0.2,0,0,0.3,0,0,0.5,0]
plt.pie(y, labels = mylabels, startangle = 180 , explode=myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
myexplode=[0.2,0,0,0.3,0,0,0.5,0]
plt.pie(y, labels = mylabels, startangle = 180 , explode=myexplode,shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
mycolors=["black","g","hotpink","r","c","m","y","blue"]
plt.pie(y, labels = mylabels, startangle = 180 ,colors=mycolors ,shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.legend(title="marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([95,87,81,96,97,96,92,77])
mylabels = ["chemistry", "clad", "it", "c lang","single","several","wokshop" ,   "venture"]
plt.Circle(y)
plt.show()
